# %%
#imprime la ultima palabra de un texto
#for line in open ( "halo_reach.txt"):
#    for word in line.split ():
#        if word.endswith ( 'he' ):
#            print (word)

# %%
import nltk
import re
import csv, operator
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml

# %%
#from nltk.book import *

# %%
text9
# Out:
# <Text: The Man Who Was Thursday by G . K . Chesterton 1908>

# %%
text1.concordance('monstrous')
# Out:
# Displaying 11 of 11 matches:
# ong the former , one was of a most monstrous size . ... This came towards us ,
# ON OF THE PSALMS . " Touching that monstrous bulk of the whale or ork we have r
# ll over with a heathenish array of monstrous clubs and spears . Some were thick
# d as you gazed , and wondered what monstrous cannibal and savage could ever hav
# that has survived the flood ; most monstrous and most mountainous ! That Himmal
# they might scout at Moby Dick as a monstrous fable , or still worse and more de
# th of Radney .'" CHAPTER 55 Of the Monstrous Pictures of Whales . I shall ere l
# ing Scenes . In connexion with the monstrous pictures of whales , I am strongly
# ere to enter upon those still more monstrous stories of them which are to be fo
# ght have been rummaged out of this monstrous cabinet there is no telling . But
# of Whale - Bones ; for Whales of a monstrous size are oftentimes cast up dead u

# %%
text1.similar('monstrous')
# Out:
# mouldy gamesome mystifying trustworthy curious lamentable horrible
# pitiable wise passing subtly puzzled lazy mean loving maddens doleful
# reliable untoward abundant

# %%
text2.similar('monstrous')
# Out:
# very exceedingly heartily so extremely great amazingly good as vast
# remarkably sweet a

# %%
text3.similar('monstrous')
# Out:
# No matches

# %%
text2.common_contexts ([ "monstrous" , "very" ])
# Out:
# be_glad is_pretty am_glad a_pretty a_lucky

# %%
text4.dispersion_plot(["citizens","democracy","freedom","duties","America"])

# %%
#text3.generate() no disponible en la version actual de nltk :/
text3
# Out:
# <Text: The Book of Genesis>

# %%
len(text3)
# Out:
# 44764

# %%
sorted(set(text3))#se obtiene una lista ordenada de elementos de vocabulario,
['!', "'", '(', ')', ',', ',)', '.', '.)', ':', ';', ';)', '?', '?)',
'A', 'Abel', 'Abelmizraim', 'Abidah', 'Abide', 'Abimael', 'Abimelech',
'Abr', 'Abrah', 'Abraham', 'Abram', 'Accad', 'Achbor', 'Adah', ...]
len(set(text3))
# Out:
# 2789

# %%
len (set (text3)) / len (text3)
# Out:
# 0.06230453042623537

# %%
text3.count("smote")
# Out:
# 5

# %%
 100 * text4.count('a')/len(text4)
# Out:
# 1.4643016433938312

# %%
def  lexical_diversity (texto):
     return len (set (texto)) / len (texto)
print(lexical_diversity(text3))
print('\n.')
lexical_diversity (text5)
# Out:
# 0.06230453042623537
#
# .
# 0.13477005109975562

# %%
def  percentage(count,total):
    return 100 * count / total
percentage(4, 5)
# Out:
# 80.0

# %%
sent1=['Call','me','Ishmael','.']
sent1
# Out:
# ['Call', 'me', 'Ishmael', '.']

# %%
len(sent1)
# Out:
# 4

# %%
lexical_diversity(sent1)
# Out:
# 1.0

# %%
sent2
# Out:
# ['The',
#  'family',
#  'of',
#  'Dashwood',
#  'had',
#  'long',
#  'been',
#  'settled',
#  'in',
#  'Sussex',
#  '.']

# %%
sent3
# Out:
# ['In',
#  'the',
#  'beginning',
#  'God',
#  'created',
#  'the',
#  'heaven',
#  'and',
#  'the',
#  'earth',
#  '.']

# %%
lista=['Jhon','Learn','code','.','la']

# %%
len(set(lista)),lista.count('la')
# Out:
# (5, 1)

# %%
#lista.append('hero')

# %%
#
text1[1],text1[2], text1[3], text1[4],text1[5],text1[6]
# Out:
# ('Moby', 'Dick', 'by', 'Herman', 'Melville', '1851')

# %%
#
text1.index('Moby'),text1.index('Dick'),text1.index('by'),text1.index('Herman'),text1.index('Melville'),text1.index('1851')
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
#Rango de seleccion de los campos de una lista x
text1[1:6]
# Out:
# ['Moby', 'Dick', 'by', 'Herman', 'Melville']

# %%
text1[:6],text1[:418],text1.index('said')
# Out:
# (['[', 'Moby', 'Dick', 'by', 'Herman', 'Melville'],
#  ['[',
#   'Moby',
#   'Dick',
#   'by',
#   'Herman',
#   'Melville',
#   '1851',
#   ']',
#   'ETYMOLOGY',
#   '.',
#   '(',
#   'Supplied',
#   'by',
#   'a',
#   'Late',
#   'Consumptive',
#   'Usher',
#   'to',
#   'a',
#   'Grammar',
#   'School',
#   ')',
#   'The',
#   'pale',
#   'Usher',
#   '--',
#   'threadbare',
#   'in',
#   'coat',
#   ',',
#   'heart',
#   ',',
#   'body',
#   ',',
#   'and',
#   'brain',
#   ';',
#   'I',
#   'see',
#   'him',
#   'now',
#   '.',
#   'He',
#   'was',
#   'ever',
#   'dusting',
#   'his',
#   'old',
#   'lexicons',
#   'and',
#   'grammars',
#   ',',
#   'with',
#   'a',
#   'queer',
#   'handkerchief',
#   ',',
#   'mockingly',
#   'embellished',
#   'with',
#   'all',
#   'the',
#   'gay',
#   'flags',
#   'of',
#   'all',
#   'the',
#   'known',
#   'nations',
#   'of',
#   'the',
#   'world',
#   '.',
#   'He',
#   'loved',
#   'to',
#   'dust',
#   'his',
#   'old',
# ...

# %%
lista
# Out:
# ['Jhon', 'Learn', 'code', '.', 'la']

# %%
sorted(lista)
# Out:
# ['.', 'Jhon', 'Learn', 'code', 'la']

# %%
':)'
# Out:
# ':)'

# %%
vocabulario=set(text1)

# %%
vocab_size=len(vocabulario)

# %%
vocab_size
# Out:
# 19317

# %%
name='Monty'

# %%
name[1]
# Out:
# 'o'

# %%
nu=re.findall('y$',name)
print(nu,' d:')
# Out:
# ['y']  d:

# %%
name[:4]
# Out:
# 'Mont'

# %%
name * 2
# Out:
# 'MontyMonty'

# %%
name+'!'
# Out:
# 'Monty!'

# %%
' y '.join(['Marcela','Libros'])
# Out:
# 'Marcela y Libros'

# %%
'Marcela y Libros'.split()
# Out:
# ['Marcela', 'y', 'Libros']

# %%
diciendo = [ 'Después' , 'todo' , 'es' , 'dicho' , 'y' , 'hecho' , 'más' , 'es' , 'dicho' , 'que' , ' hecho ' ]

# %%
tokens=set(diciendo)
tokens
# Out:
# {' hecho ', 'Después', 'dicho', 'es', 'hecho', 'más', 'que', 'todo', 'y'}

# %%
tokens=sorted(tokens)
tokens
# Out:
# [' hecho ', 'Después', 'dicho', 'es', 'hecho', 'más', 'que', 'todo', 'y']

# %%
tokens[-2:]
# Out:
# ['todo', 'y']

# %%
texto_halo=[]
with open('halo_reach.txt') as miarchivo:
        #lectura por lineas csv
        registro= miarchivo.read().splitlines()
        #eliminar nombres cada columna
        registro.pop(0)
        
    #almacenamiento de datos en csv
for reg in registro:
    linea= reg.split(',')
        #almacenamiento de datos
    texto_halo.append(linea)

# %%
finLis= FreqDist(text1)
print(finLis)
len(finLis)
# Out:
# <FreqDist with 19317 samples and 260819 outcomes>
# 19317

# %%
finLis.most_common(30)
# Out:
# [(',', 18713),
#  ('the', 13721),
#  ('.', 6862),
#  ('of', 6536),
#  ('and', 6024),
#  ('a', 4569),
#  ('to', 4542),
#  (';', 4072),
#  ('in', 3916),
#  ('that', 2982),
#  ("'", 2684),
#  ('-', 2552),
#  ('his', 2459),
#  ('it', 2209),
#  ('I', 2124),
#  ('s', 1739),
#  ('is', 1695),
#  ('he', 1661),
#  ('with', 1659),
#  ('was', 1632),
#  ('as', 1620),
#  ('"', 1478),
#  ('all', 1462),
#  ('for', 1414),
#  ('this', 1280),
#  ('!', 1269),
#  ('at', 1231),
#  ('by', 1137),
#  ('but', 1113),
#  ('not', 1103)]

# %%
finLis['not']
# Out:
# 1103

# %%
finLis2=FreqDist(text2)

# %%
finLis2.most_common(23)
# Out:
# [(',', 9397),
#  ('to', 4063),
#  ('.', 3975),
#  ('the', 3861),
#  ('of', 3565),
#  ('and', 3350),
#  ('her', 2436),
#  ('a', 2043),
#  ('I', 2004),
#  ('in', 1904),
#  ('was', 1846),
#  ('it', 1568),
#  ('"', 1506),
#  (';', 1419),
#  ('she', 1333),
#  ('be', 1305),
#  ('that', 1297),
#  ('for', 1234),
#  ('not', 1212),
#  ('as', 1179),
#  ('you', 1037),
#  ('with', 971),
#  ('had', 969)]

# %%
finLis2['dog']
# Out:
# 1

# %%
finLis['like']
# Out:
# 624

# %%
finLis.plot(50, cumulative=True)

# %%
finLis.hapaxes()
# Out:
# ['nosed',
#  'piping',
#  'carnivorous',
#  'intimacy',
#  'unprejudiced',
#  'enumerate',
#  'cultivated',
#  'Mt',
#  'maddens',
#  'couch',
#  'metres',
#  'scorches',
#  'crackled',
#  'Nathan',
#  'tapered',
#  'vum',
#  'waterless',
#  'baptism',
#  'miss',
#  'loitering',
#  'particles',
#  'maple',
#  'butcher',
#  'tat',
#  'Bonneterre',
#  "?--'",
#  'expound',
#  'ravens',
#  'bolting',
#  'vacillations',
#  'loungingly',
#  'entreaties',
#  'Persians',
#  'vicariously',
#  'Navis',
#  'narrower',
#  'rainy',
#  'abate',
#  '124',
#  'charges',
#  'Madame',
#  'Peering',
#  'FIFE',
#  'Ashantee',
#  'slantings',
#  'veal',
#  'moors',
#  'renounced',
#  'dismasting',
#  'Forced',
#  'Oceanica',
#  'victories',
#  'consecrating',
#  'vexatious',
#  'RICHARD',
#  'Trade',
#  'tips',
#  'witch',
#  'topers',
#  'perpetuated',
#  'genuineness',
#  'sog',
#  'restrained',
#  'legitimately',
#  'audible',
#  'carnation',
#  'leach',
#  'friar',
#  'sultan',
#  'divinest',
# ...

# %%
v = set(text1)

# %%
long_words=[w for w in v if len(w)>15] 
long_words
# Out:
# ['characteristically',
#  'responsibilities',
#  'circumnavigation',
#  'hermaphroditical',
#  'cannibalistically',
#  'uncompromisedness',
#  'irresistibleness',
#  'circumnavigations',
#  'circumnavigating',
#  'Physiognomically',
#  'indispensableness',
#  'simultaneousness',
#  'uninterpenetratingly',
#  'supernaturalness',
#  'superstitiousness',
#  'subterraneousness',
#  'indiscriminately',
#  'preternaturalness',
#  'uncomfortableness',
#  'apprehensiveness',
#  'comprehensiveness',
#  'CIRCUMNAVIGATION',
#  'undiscriminating',
#  'physiognomically']

# %%
sorted(long_words)
# Out:
# ['CIRCUMNAVIGATION',
#  'Physiognomically',
#  'apprehensiveness',
#  'cannibalistically',
#  'characteristically',
#  'circumnavigating',
#  'circumnavigation',
#  'circumnavigations',
#  'comprehensiveness',
#  'hermaphroditical',
#  'indiscriminately',
#  'indispensableness',
#  'irresistibleness',
#  'physiognomically',
#  'preternaturalness',
#  'responsibilities',
#  'simultaneousness',
#  'subterraneousness',
#  'supernaturalness',
#  'superstitiousness',
#  'uncomfortableness',
#  'uncompromisedness',
#  'undiscriminating',
#  'uninterpenetratingly']

# %%
fdits1= FreqDist(text1)

# %%
fdits1
# Out:
# FreqDist({'nosed': 1,
#           'brags': 1,
#           'attempt': 9,
#           'intimacy': 1,
#           'vibration': 5,
#           'unreasoning': 3,
#           'interfering': 1,
#           'splinters': 5,
#           'enumerate': 1,
#           'moisture': 4,
#           'DEVIL': 1,
#           'cultivated': 1,
#           'maddens': 1,
#           'wearing': 4,
#           'naval': 3,
#           'heave': 16,
#           'scorches': 1,
#           'overhead': 6,
#           'dyspepsia': 4,
#           'planted': 13,
#           'vum': 1,
#           'noblemen': 1,
#           'tremendous': 9,
#           'plough': 1,
#           'boom': 8,
#           'observation': 5,
#           'sufficient': 5,
#           'quietly': 18,
#           'tackle': 11,
#           'Eastern': 2,
#           'butcher': 1,
#           'substituting': 2,
#           'Oriental': 6,
#           'Bonneterre': 1,
#           'unprovided': 3,
#           'windlass': 21,
#           'mosses': 3,
# ...

# %%
print(sorted(j for j in set(text1) if len(j) > 7 and fdits1[j] > 7))
# Out:
# ['American', 'Atlantic', 'Bulkington', 'Canallers', 'Christian', 'Commodore', 'Consider', 'Fedallah', 'Greenland', 'Guernsey', 'Heidelburgh', 'Japanese', 'Jeroboam', 'Leviathan', 'Meantime', 'Meanwhile', 'Mediterranean', 'Moreover', 'NANTUCKET', 'Nantucket', 'Nantucketer', 'Nantucketers', 'Nevertheless', 'Porpoise', 'Queequeg', 'Scoresby', 'Sebastian', 'Starbuck', 'Steelkilt', 'Tashtego', 'Therefore', 'Wherefore', 'abounding', 'according', 'accounted', 'accounts', 'accursed', 'activity', 'actually', 'additional', 'advanced', 'advancing', 'afternoon', 'afterwards', 'alongside', 'altogether', 'ambergris', 'answered', 'anything', 'anywhere', 'appalling', 'apparently', 'apparition', 'appearance', 'appeared', 'approaching', 'archangel', 'articles', 'attached', 'attention', 'authority', 'backward', 'barbaric', 'beautiful', 'beginning', 'beholding', 'belonged', 'belonging', 'bestowed', 'binnacle', 'blackness', 'blacksmith', 'bowsprit', 'breakfast', 'breaking', 'bringing', 'bulwarks', 'burst
# ...

# %%
text1.collocations()
# Out:
# Sperm Whale; Moby Dick; White Whale; old man; Captain Ahab; sperm
# whale; Right Whale; Captain Peleg; New Bedford; Cape Horn; cried Ahab;
# years ago; lower jaw; never mind; Father Mapple; cried Stubb; chief
# mate; white whale; ivory leg; one hand

# %%
l_tex_halo= FreqDist(texto_halo)
