# %% [markdown]
# ## promedio word by user

# %%
import pandas as pd
from nltk import tokenize
import nltk 

import random

import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import plotly.plotly as py
from time import time

# %% [markdown]
# ## read excel

# %%
def reading_csv(dir):
    start = time()
    dataframe = pd.read_excel(dir)
    print('Save +'+dir+' in dataframe %.2f seconds' % (time() - start))
    return dataframe

dataframe = reading_csv('chatccb_full_mar_2016.xlsx')
# Out:
# Cleaning took 550.76 seconds

# %%
total_records = len(dataframe['id sesion'])
total_records

# %% [markdown]
# ## filtrer by only sesion id and agent

# %%
#only_one_chat= ' '.join(chat_user['mensaje'].get_values())
def filter_chat(dataframelist):
    df = dataframelist.loc[dataframelist['id sesion'] == dataframelist['id sesion']]
    df =  df.loc[(df['tipo participante'] == 'Usuario')]
    return df
datafram_filtered = filter_chat(dataframe)
print(len(datafram_filtered))
datafram_filtered.dropna(subset=['mensaje'], inplace=True)
datafram_filtered['cant_tokens'] = datafram_filtered['mensaje'].apply(lambda token:len(tokenize.word_tokenize(str(token))))
# Out:
# 454326

# %%
promedio_am = datafram_filtered.groupby('id sesion').apply(lambda row: row['cant_tokens'].sum()/len(row)).values.tolist()

# %%
#test = datafram_filtered.loc[datafram_filtered['id sesion'] == '34f5th1503292']
#test.dropna(subset=['mensaje'], inplace=True)
#dropna(subset=['Tenant'], inplace=True)
promedio_am
# Out:
# [4.8,
#  8.705882352941176,
#  6.1891891891891895,
#  6.166666666666667,
#  6.45,
#  9.0,
#  4.5,
#  11.333333333333334,
#  6.25,
#  15.6,
#  10.333333333333334,
#  4.0,
#  7.666666666666667,
#  8.117647058823529,
#  6.333333333333333,
#  3.0,
#  5.769230769230769,
#  5.0,
#  17.0,
#  13.75,
#  3.5,
#  10.0,
#  6.75,
#  14.5,
#  3.2,
#  5.25,
#  9.666666666666666,
#  8.3,
#  24.25,
#  11.5,
#  13.5,
#  6.75,
#  10.0,
#  3.5454545454545454,
#  16.0,
#  18.5,
#  14.966666666666667,
#  7.428571428571429,
#  9.0,
#  9.333333333333334,
#  11.333333333333334,
#  8.6,
#  10.666666666666666,
#  13.5,
#  5.0,
#  5.3,
#  6.333333333333333,
#  14.88888888888889,
#  8.5,
#  5.166666666666667,
#  17.333333333333332,
#  5.2,
#  6.818181818181818,
#  9.0,
#  7.181818181818182,
#  1.0,
#  4.833333333333333,
#  9.0,
#  8.0,
#  5.6,
#  4.2,
#  29.5,
#  7.3,
#  11.333333333333334,
#  14.0,
#  9.40625,
#  9.636363636363637,
#  5.777777777777778,
#  10.666666666666666,
#  5.5,
#  9.3,
# ...

# %% [markdown]
# ## delete of duplicate id sesion

# %%
dataframe_unique_sesion = datafram_filtered.drop_duplicates(subset='id sesion')

# %%
len(dataframe_unique_sesion)
# Out:
# 54852

# %% [markdown]
# ## average_word_number_by_user

# %%
def set_promedio_word(dataframfiltered,id_session):
    chat_only_user = dataframfiltered.loc[dataframfiltered['id sesion'] == id_session]
    count_chat = 0
    number_words = 0
    promedio_list = []

    while count_chat <=  (len(chat_only_user['mensaje'])-1):
        number_words=number_words + len(tokenize.word_tokenize(chat_only_user['mensaje'].iloc[count_chat]))
        count_chat = count_chat +1
    number_words = number_words/count_chat
    promedio_list.append([number_words,count_chat])
    return promedio_list

def number_word(dataframfiltered,id_session):
    chat_only_user = dataframfiltered.loc[dataframfiltered['id sesion'] == id_session]
    count_chat = 0
    while count_chat <=  (len(chat_only_user['mensaje'])-1):
        count_chat = count_chat +1
    return count_chat

# %% [markdown]
# ## extract_promedio

# %%
#lista1 = []

#for index ,row in dataframe_unique_sesion['id sesion'].iteritems():
 #   numberword = number_word(datafram_filtered,row)
  #  lista1.append(number_word)

# %%
#promedio_list = []
#flag_int = 0
#for index ,row in dataframe_unique_sesion['id sesion'].iteritems():
    #print(row,flag_int)
   # promedio = set_promedio_word(datafram_filtered,row)
  #  promedio_list.append([promedio,row])
    #print('promedio-> ',promedio,'sesion id-> ',row)
 #   flag_int = flag_int +1
#newDataframe = pd.DataFrame(promedio_list, columns=['session id','promedio_words'])
#newDataframe
#promedio_list

# %%
flag_int = 0
lista = []
listapromedio = newDataframe['session id']#
while flag_int <=  (len(listapromedio)-1):
    lista.append(listapromedio.loc[flag_int][0][0])
    flag_int = flag_int +1 
#lista
#promedios_word = np.asarray(lista)
#newDataframe

# %%
#006v2q1532845 = 20
len(promedios_word)
# Out:
# 54852

# %%
#newDataframe
# promedios lista
# Out:
# [4.8,
#  8.705882352941176,
#  6.1891891891891895,
#  6.166666666666667,
#  6.45,
#  9.0,
#  4.5,
#  11.333333333333334,
#  6.25,
#  15.6,
#  10.333333333333334,
#  4.0,
#  7.666666666666667,
#  8.117647058823529,
#  6.333333333333333,
#  3.0,
#  5.769230769230769,
#  5.0,
#  17.0,
#  13.75,
#  3.5,
#  10.0,
#  6.75,
#  14.5,
#  3.2,
#  5.25,
#  9.666666666666666,
#  8.3,
#  24.25,
#  11.5,
#  13.5,
#  6.75,
#  10.0,
#  3.5454545454545454,
#  16.0,
#  18.5,
#  14.966666666666667,
#  7.428571428571429,
#  9.0,
#  9.333333333333334,
#  11.333333333333334,
#  8.6,
#  10.666666666666666,
#  13.5,
#  5.0,
#  5.3,
#  6.333333333333333,
#  14.88888888888889,
#  8.5,
#  5.166666666666667,
#  17.333333333333332,
#  5.2,
#  6.818181818181818,
#  9.0,
#  7.181818181818182,
#  1.0,
#  4.833333333333333,
#  9.0,
#  8.0,
#  5.6,
#  4.2,
#  29.5,
#  7.3,
#  11.333333333333334,
#  14.0,
#  9.40625,
#  9.636363636363637,
#  5.777777777777778,
#  10.666666666666666,
#  5.5,
#  9.3,
# ...

# %% [markdown]
# ## graph promedio words by chat

# %%
freq = nltk.FreqDist(tokenchat)
print(freq)

# %%
'cantidad de palabras por conversacion -> ',len(only_one_chat), ' ', chat_user['participante'].iloc[0]

# %%
histogram=plt.figure()

x = [random.gauss(3,1) for _ in range(400)]
y = [random.gauss(4,2) for _ in range(400)]

bins = np.linspace(-45, 45, 100)

plt.hist(x, bins, alpha=0.5)
plt.hist(promedio_am, bins)
plt.show()

# %%
#chatunique = ' '.join(chat_user['mensaje'].get_values())
#tokenchat = tokenize.word_tokenize(chatunique)

# %%
chat_user['participante'].iloc[0]

# %%
only_one_chat = len(tokenize.word_tokenize(chat_user['mensaje'].iloc[0]))
only_one_chat

# %%
#chat_test #dtype=object
#chat_test.loc[(chat_test['agente'] == chat_test['agente'].iloc[0]) != (chat_test['participante'] == chat_test['agente'].iloc[0])]

# %%
#only_sesion = dataframe['sesion id'].iloc[0]
#onli_user =  only_sesion.loc[(only_sesion['agente'] == only_sesion['agente'].iloc[0]) != (only_sesion['participante'] == only_sesion['agente'].iloc[0])]
#only_sesion

# %%
"""
https://stackoverflow.com/questions/17063458/reading-an-excel-file-in-python-using-pandas
http://pandas.pydata.org/pandas-docs/version/0.17.1/indexing.html
https://stackoverflow.com/questions/17071871/select-rows-from-a-dataframe-based-on-values-in-a-column-in-pandas
https://stackoverflow.com/questions/15315452/selecting-with-complex-criteria-from-pandas-dataframe
https://chrisalbon.com/python/data_wrangling/pandas_selecting_rows_on_conditions/
https://stackoverflow.com/questions/22086116/how-do-you-filter-pandas-dataframes-by-multiple-columns
https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html
https://pandas.pydata.org/pandas-docs/stable/merging.html
https://stackoverflow.com/questions/25254016/pandas-get-first-row-value-of-a-given-column
https://matplotlib.org/examples/statistics/histogram_demo_multihist.html
https://www.datacamp.com/community/tutorials/pandas-tutorial-dataframe-python
https://plot.ly/matplotlib/histograms/
https://matplotlib.org/1.2.1/examples/pylab_examples/histogram_demo.html
http://pandas.pydata.org/pandas-docs/version/0.17.0/generated/pandas.DataFrame.iterrows.html
https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.drop_duplicates.html
https://stackoverflow.com/questions/29314033/python-pandas-dataframe-remove-empty-cells
"""

# %%
np.random.seed(0)

n_bins = 10
x = np.random.randn(1000, 3)

fig, axes = plt.subplots(nrows=2, ncols=2)
ax0, ax1, ax2, ax3 = axes.flatten()

colors = ['red', 'tan', 'lime']
ax0.hist(x, n_bins, normed=1, histtype='bar', color=colors, label=colors)
ax0.legend(prop={'size': 10})
ax0.set_title('bars with legend')

ax1.hist(x, n_bins, normed=1, histtype='bar', stacked=True)
ax1.set_title('stacked bar')

ax2.hist(x, n_bins, histtype='step', stacked=True, fill=False)
ax2.set_title('stack step (unfilled)')

# Make a multiple-histogram of data-sets with different length.
x_multi = [np.random.randn(n) for n in [10000, 5000, 2000]]
ax3.hist(x_multi, n_bins, histtype='bar')
ax3.set_title('different sample sizes')

fig.tight_layout()
plt.show()

# %%
total_records = 0
while total_records <= (len(dataframe['sesion id'])-1):
    
    only_user = filter_chat(dataframe,total_records) 
    
    promedio_words = set_promedio_word(only_user)    
    
    #print(promedio_words)
    
    total_records = total_records + 1
