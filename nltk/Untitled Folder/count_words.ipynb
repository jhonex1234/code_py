# %% [markdown]
# ## promedio word by user

# %%
import pandas as pd
from nltk import tokenize
import nltk 

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## read excel

# %%
def reading_csv(dir):
    dataframe = pd.read_excel(dir)
    return dataframe

dataframe = pd.read_excel('chatccb_ago_2017.xlsx')

# %% [markdown]
# ## filtrer by sesion id

# %%
chat_test = dataframe.loc[dataframe['sesion id'] == '006pks2178245']

# %%
chat_test #dtype=object
# Out:
#                            grupo chat        fecha sesion      sesion id  \
# 0   Chat Cámara de Comercio de Bogotá 2017-08-03 22:18:40  006pks2178245
# 1   Chat Cámara de Comercio de Bogotá 2017-08-03 22:18:40  006pks2178245
# 3   Chat Cámara de Comercio de Bogotá 2017-08-03 22:18:40  006pks2178245
# 4   Chat Cámara de Comercio de Bogotá 2017-08-03 22:18:40  006pks2178245
# 5   Chat Cámara de Comercio de Bogotá 2017-08-03 22:18:40  006pks2178245
# 6   Chat Cámara de Comercio de Bogotá 2017-08-03 22:18:40  006pks2178245
# 7   Chat Cámara de Comercio de Bogotá 2017-08-03 22:18:40  006pks2178245
# 8   Chat Cámara de Comercio de Bogotá 2017-08-03 22:18:40  006pks2178245
# 9   Chat Cámara de Comercio de Bogotá 2017-08-03 22:18:40  006pks2178245
# 10  Chat Cámara de Comercio de Bogotá 2017-08-03 22:18:40  006pks2178245
# 11  Chat Cámara de Comercio de Bogotá 2017-08-03 22:18:40  006pks2178245
# 12  Chat Cámara de Comercio de Bogotá 2017-08-03 22:18:40  006pks2178245
# 13  Chat Cámara de Comercio de Bogotá 2017-08-03 22:18:40  006pks2178245
# 14  Chat Cámara de Comercio de Bogotá 2017-08-03 22:18:40  006pks2178245
# 15  Chat Cámara de Comercio de Bogotá 2017-08-03 22:18:40  006pks2178245
# 16  Chat Cámara de Comercio de Bogotá 2017-08-03 22:18:40  006pks2178245
# 17  Chat Cámara de Comercio de Bogotá 2017-08-03 22:18:40  006pks2178245
#
#                tipificacion                       subtipificacion  \
# 0   REGISTRO DE PROPONENTES  MATRICULA DE REGISTRO DE PROPONENTES
# 1   REGISTRO DE PROPONENTES  MATRICULA DE REGISTRO DE PROPONENTES
# 3   REGISTRO DE PROPONENTES  MATRICULA DE REGISTRO DE PROPONENTES
# 4   REGISTRO DE PROPONENTES  MATRICULA DE REGISTRO DE PROPONENTES
# 5   REGISTRO DE PROPONENTES  MATRICULA DE REGISTRO DE PROPONENTES
# 6   REGISTRO DE PROPONENTES  MATRICULA DE REGISTRO DE PROPONENTES
# 7   REGISTRO DE PROPONENTES  MATRICULA DE REGISTRO DE PROPONENTES
# 8   REGISTRO DE PROPONENTES  MATRICULA DE REGISTRO DE PROPONENTES
# 9   REGISTRO DE PROPONENTES  MATRICULA DE REGISTRO DE PROPONENTES
# 10  REGISTRO DE PROPONENTES  MATRICULA DE REGISTRO DE PROPONENTES
# 11  REGISTRO DE PROPONENTES  MATRICULA DE REGISTRO DE PROPONENTES
# 12  REGISTRO DE PROPONENTES  MATRICULA DE REGISTRO DE PROPONENTES
# 13  REGISTRO DE PROPONENTES  MATRICULA DE REGISTRO DE PROPONENTES
# 14  REGISTRO DE PROPONENTES  MATRICULA DE REGISTRO DE PROPONENTES
# 15  REGISTRO DE PROPONENTES  MATRICULA DE REGISTRO DE PROPONENTES
# 16  REGISTRO DE PROPONENTES  MATRICULA DE REGISTRO DE PROPONENTES
# 17  REGISTRO DE PROPONENTES  MATRICULA DE REGISTRO DE PROPONENTES
#
#                                            clean text         agente  \
# 0   buen tard bienven chat cam comerci bogot pued ...  carlos.vargas
# 1   graci devuelt inscripcion rup retom tramit nue...  carlos.vargas
# 3   indic favor numer tramit resalt part inferior ...  carlos.vargas
# 4                                                 NaN  carlos.vargas
# 5   senor garci reingres document necesari ingres ...  carlos.vargas
# 6                                               graci  carlos.vargas
# 7                               gust pued colabor mas  carlos.vargas
# 8                                      deb inici nuev  carlos.vargas
# 9     senor retom tramit numer solicitud inici tramit  carlos.vargas
# 10                                              graci  carlos.vargas
# 11                              gust pued colabor mas  carlos.vargas
# 12     numer solicitud pid sistem doy numer recib noo  carlos.vargas
# 13  numer ingres anterior sistem deb valid corre e...  carlos.vargas
# 14                                              graci  carlos.vargas
# 15                              gust pued colabor mas  carlos.vargas
# 16                                              graci  carlos.vargas
# 17  senor garci suen empres graci utiliz chat cam ...  carlos.vargas
#
#      participante       fecha mensaje  \
# 0   carlos.vargas 2017-08-03 22:18:43
# 1   WILMAR GARCIA 2017-08-03 22:20:18
# 3   carlos.vargas 2017-08-03 22:20:50
# 4   WILMAR GARCIA 2017-08-03 22:22:24
# 5   carlos.vargas 2017-08-03 22:24:19
# 6   WILMAR GARCIA 2017-08-03 22:24:36
# 7   carlos.vargas 2017-08-03 22:24:56
# 8   WILMAR GARCIA 2017-08-03 22:25:00
# 9   carlos.vargas 2017-08-03 22:26:50
# 10  WILMAR GARCIA 2017-08-03 22:27:50
# 11  carlos.vargas 2017-08-03 22:28:59
# 12  WILMAR GARCIA 2017-08-03 22:29:40
# 13  carlos.vargas 2017-08-03 22:30:40
# 14  WILMAR GARCIA 2017-08-03 22:31:20
# 15  carlos.vargas 2017-08-03 22:31:26
# 16  WILMAR GARCIA 2017-08-03 22:32:00
# 17  carlos.vargas 2017-08-03 22:32:08
#
#                                               mensaje
# 0   Buenas Tardes, bienvenido al chat de la Cámara...
# 1   gracias , me fue devuelto la inscripcion del  ...
# 3   Me indica por favor el número de trámite. Está...
# 4                                              382927
# 5   Señor Garcia, para reingresar los documentos e...
# 6                                             gracias
# 7   Con mucho gusto, ¿le puedo colaborar en algo m...
# 8                      o sea debo iniciarlo de nuevo?
# 9   No señor, tiene que retomar tramite con el num...
# 10                                         ok gracias
# 11  Con mucho gusto, ¿le puedo colaborar en algo m...
# 12  como se mi numero de solicitud que me pide el ...
# 13  Es el numero con el que ingreso anteriormente ...
# 14                                         ok gracias
# 15  Con mucho gusto, ¿le puedo colaborar en algo m...
# 16                                      no sr gracias
# 17  Señor Garcia, sus sueños son nuestra empresa, ...

# %% [markdown]
# ## filtrer message agent

# %%
chat_user = chat_test.loc[(dataframe['agente'] == 'carlos.vargas') != (dataframe['participante'] == 'carlos.vargas')] 
chat_user
# Out:
#                            grupo chat        fecha sesion      sesion id  \
# 1   Chat Cámara de Comercio de Bogotá 2017-08-03 22:18:40  006pks2178245
# 4   Chat Cámara de Comercio de Bogotá 2017-08-03 22:18:40  006pks2178245
# 6   Chat Cámara de Comercio de Bogotá 2017-08-03 22:18:40  006pks2178245
# 8   Chat Cámara de Comercio de Bogotá 2017-08-03 22:18:40  006pks2178245
# 10  Chat Cámara de Comercio de Bogotá 2017-08-03 22:18:40  006pks2178245
# 12  Chat Cámara de Comercio de Bogotá 2017-08-03 22:18:40  006pks2178245
# 14  Chat Cámara de Comercio de Bogotá 2017-08-03 22:18:40  006pks2178245
# 16  Chat Cámara de Comercio de Bogotá 2017-08-03 22:18:40  006pks2178245
#
#                tipificacion                       subtipificacion  \
# 1   REGISTRO DE PROPONENTES  MATRICULA DE REGISTRO DE PROPONENTES
# 4   REGISTRO DE PROPONENTES  MATRICULA DE REGISTRO DE PROPONENTES
# 6   REGISTRO DE PROPONENTES  MATRICULA DE REGISTRO DE PROPONENTES
# 8   REGISTRO DE PROPONENTES  MATRICULA DE REGISTRO DE PROPONENTES
# 10  REGISTRO DE PROPONENTES  MATRICULA DE REGISTRO DE PROPONENTES
# 12  REGISTRO DE PROPONENTES  MATRICULA DE REGISTRO DE PROPONENTES
# 14  REGISTRO DE PROPONENTES  MATRICULA DE REGISTRO DE PROPONENTES
# 16  REGISTRO DE PROPONENTES  MATRICULA DE REGISTRO DE PROPONENTES
#
#                                            clean text         agente  \
# 1   graci devuelt inscripcion rup retom tramit nue...  carlos.vargas
# 4                                                 NaN  carlos.vargas
# 6                                               graci  carlos.vargas
# 8                                      deb inici nuev  carlos.vargas
# 10                                              graci  carlos.vargas
# 12     numer solicitud pid sistem doy numer recib noo  carlos.vargas
# 14                                              graci  carlos.vargas
# 16                                              graci  carlos.vargas
#
#      participante       fecha mensaje  \
# 1   WILMAR GARCIA 2017-08-03 22:20:18
# 4   WILMAR GARCIA 2017-08-03 22:22:24
# 6   WILMAR GARCIA 2017-08-03 22:24:36
# 8   WILMAR GARCIA 2017-08-03 22:25:00
# 10  WILMAR GARCIA 2017-08-03 22:27:50
# 12  WILMAR GARCIA 2017-08-03 22:29:40
# 14  WILMAR GARCIA 2017-08-03 22:31:20
# 16  WILMAR GARCIA 2017-08-03 22:32:00
#
#                                               mensaje
# 1   gracias , me fue devuelto la inscripcion del  ...
# 4                                              382927
# 6                                             gracias
# 8                      o sea debo iniciarlo de nuevo?
# 10                                         ok gracias
# 12  como se mi numero de solicitud que me pide el ...
# 14                                         ok gracias
# 16                                      no sr gracias

# %% [markdown]
# ##average word number by user

# %%
#only_one_chat= ' '.join(chat_user['mensaje'].get_values())
total_chat = len(chat_user['mensaje'])
a = 0
number_words = 0
for chat in chat_user['mensaje']:
    a = a +1
    number_words=number_words + len(tokenize.word_tokenize(chat))
#promedio
number_words / a

# %%
chat_user['mensaje'].iloc[0]
# Out:
# 'gracias , me fue devuelto la inscripcion del  rup, como retomo el tramite para el nuevo esquema grafico , o me toca iniciar de nuevo el tramite de inscripcion? gracias\n  nit \n9002395730'

# %%
chat_user['participante'].iloc[0]
# Out:
# 'WILMAR GARCIA'

# %%
only_one_chat = len(tokenize.word_tokenize(chat_user['mensaje'].iloc[0]))
only_one_chat
# Out:
# 34

# %%
freq = nltk.FreqDist(only_one_chat)
print(freq)
# Out:
# <FreqDist with 44 samples and 70 outcomes>

# %%
'cantidad de palabras por conversacion -> ',len(only_one_chat), ' ', chat_user['participante'].iloc[0]

# %%
np.random.seed(0)

n_bins = 10
x = np.random.randn(1000, 3)

fig, axes = plt.subplots(nrows=2, ncols=2)
ax0, ax1, ax2, ax3 = axes.flatten()

colors = ['red', 'tan', 'lime']
ax0.hist(x, n_bins, normed=1, histtype='bar', color=colors, label=colors)
ax0.legend(prop={'size': 10})
ax0.set_title('bars with legend')

ax1.hist(x, n_bins, normed=1, histtype='bar', stacked=True)
ax1.set_title('stacked bar')

ax2.hist(x, n_bins, histtype='step', stacked=True, fill=False)
ax2.set_title('stack step (unfilled)')

# Make a multiple-histogram of data-sets with different length.
x_multi = [np.random.randn(n) for n in [10000, 5000, 2000]]
ax3.hist(x_multi, n_bins, histtype='bar')
ax3.set_title('different sample sizes')

fig.tight_layout()
plt.show()

# %%
"""
https://stackoverflow.com/questions/17063458/reading-an-excel-file-in-python-using-pandas
http://pandas.pydata.org/pandas-docs/version/0.17.1/indexing.html
https://stackoverflow.com/questions/17071871/select-rows-from-a-dataframe-based-on-values-in-a-column-in-pandas
https://stackoverflow.com/questions/15315452/selecting-with-complex-criteria-from-pandas-dataframe
https://chrisalbon.com/python/data_wrangling/pandas_selecting_rows_on_conditions/
https://stackoverflow.com/questions/22086116/how-do-you-filter-pandas-dataframes-by-multiple-columns
https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html
https://pandas.pydata.org/pandas-docs/stable/merging.html
https://stackoverflow.com/questions/25254016/pandas-get-first-row-value-of-a-given-column

"""
